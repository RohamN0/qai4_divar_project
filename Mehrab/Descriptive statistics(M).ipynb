# %%
import pandas as pd

# %%
col = ['cat2_slug', 'cat3_slug', 'description', 'construction_year']
df = pd.read_csv(r'C:\Users\rezaei\OneDrive\Documents\Bootcamp\pro\Divar.csv', usecols=col)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   cat2_slug          1000000 non-null  object
#  1   cat3_slug          999999 non-null   object
#  2   description        1000000 non-null  object
#  3   construction_year  815828 non-null   object
# dtypes: object(4)
# memory usage: 30.5+ MB

# %%
df1 = df.copy()

# %%
df1 = df[['cat2_slug', 'cat3_slug']]

# %%
df1.head(10)
# Out:
#           cat2_slug       cat3_slug
# 0    temporary-rent           villa
# 1  residential-sell  apartment-sell
# 2  residential-rent  apartment-rent
# 3   commercial-rent     office-rent
# 4  residential-sell  apartment-sell
# 5  residential-rent  apartment-rent
# 6   commercial-rent     office-rent
# 7  residential-sell  apartment-sell
# 8  residential-sell  apartment-sell
# 9  residential-sell  apartment-sell

# %%
df1[df1.cat3_slug.isna()]
# Out:
#               cat2_slug cat3_slug
# 338801  commercial-rent       NaN

# %%
df1[df1.cat2_slug == 'commercial-rent'].value_counts()
# Out:
# cat2_slug        cat3_slug
# commercial-rent  shop-rent                             45993
#                  office-rent                           21418
#                  industry-agriculture-business-rent     9155
# Name: count, dtype: int64

# %%
df[df.cat3_slug.isna()][['description']]
# Out:
#                                               description
# 338801  از بانوان حرفه ای و دارای مشتری دعوت میشود به ...

# %%
df.loc[338801, 'description']
# Out:
# 'از بانوان حرفه ای و دارای مشتری دعوت میشود به مجموعه ما با شرایط همکاری عالی و قیمت مناسب بپیوندید؛\n\nما در آموزشگاه و سالن زیبایی بانو یارمحمدی \nآماده همکاری جهت آموزش و خدمات \nدر لاین های زیر هستیم :\nخدمات میکاپ\nخدمات شینیون\nخدمات ناخن \nخدمات مژه\nخدمات اکستنشن مو\nخدمات پوست\nبافت مو\nخدمات پدیکور\n❌ فقط تماس بگیرید لطفا ❌'

# %%
df.head(10)
# Out:
#           cat2_slug       cat3_slug  \
# 0    temporary-rent           villa
# 1  residential-sell  apartment-sell
# 2  residential-rent  apartment-rent
# 3   commercial-rent     office-rent
# 4  residential-sell  apartment-sell
# 5  residential-rent  apartment-rent
# 6   commercial-rent     office-rent
# 7  residential-sell  apartment-sell
# 8  residential-sell  apartment-sell
# 9  residential-sell  apartment-sell
#
#                                          description construction_year
# 0  ۵۰۰متر\n۲۰۰متر بنا دوبلکس\n۳خواب\nاستخر آبگرم ...               NaN
# 1  دسترسی عالی به مترو و شریعتی \nمشاعات تمیز \nب...              ۱۳۸۴
# 2                                    تخلیه پایان ماه              ۱۴۰۱
# 3  فرشته تاپ لوکیشن\n۹۰ متر موقعیت اداری\nیک اتاق...              ۱۴۰۰
# 4  هلدینگ ساختمانی اکبری\n\nهمراه شما هستیم برای ...              ۱۴۰۳
# 5  اپارتمان ۱۰۰متری واحد جلو دارای دو اتاق خواب ک...              ۱۳۸۹
# 6  ♦مشاورین املاک سیب♦\n✅️کد:G۱۰۵\n♦با سالها سابق...              ۱۳۹۵
# 7  ♡♡♡♡♡♡بنام خدا♡♡♡♡♡♡\n♡♡♡عرض ادب واحترام♡♡♡\n♡...              ۱۳۹۳
# 8  با سلام\n\nاملاک بزرگ اتحاد با ۲شعبه فعال با ف...              ۱۳۹۶
# 9  اول رسالت فرد  نزدیک به حاشیه فرامرز .. ساکنین...              ۱۳۸۷

# %%
df1["cat3_slug"] = df1["cat3_slug"].fillna("industry-agriculture-business-rent")
# Out:
# C:\Users\rezaei\AppData\Local\Temp\ipykernel_12340\1608940251.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["cat3_slug"] = df1["cat3_slug"].fillna("industry-agriculture-business-rent")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   cat2_slug  1000000 non-null  object
#  1   cat3_slug  1000000 non-null  object
# dtypes: object(2)
# memory usage: 15.3+ MB

# %%
import matplotlib.pyplot as plt
df1['cat3_slug'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cat3_slug'>

# %%
df1['cat2_slug'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cat2_slug'>

# %%
figs, axes  = plt.subplots(1, 2, figsize=(18, 6))
df1['cat2_slug'].value_counts().plot(kind='bar', ax=axes[0])
df1['cat3_slug'].value_counts().plot(kind='bar', ax=axes[1])
plt.show()

# %% [markdown]
# # Part 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   cat2_slug          1000000 non-null  object
#  1   cat3_slug          999999 non-null   object
#  2   description        1000000 non-null  object
#  3   construction_year  815828 non-null   object
# dtypes: object(4)
# memory usage: 30.5+ MB

# %%
df[['construction_year']].head(20)
# Out:
#    construction_year
# 0                NaN
# 1               ۱۳۸۴
# 2               ۱۴۰۱
# 3               ۱۴۰۰
# 4               ۱۴۰۳
# 5               ۱۳۸۹
# 6               ۱۳۹۵
# 7               ۱۳۹۳
# 8               ۱۳۹۶
# 9               ۱۳۸۷
# 10              ۱۴۰۳
# 11              ۱۳۸۵
# 12              ۱۴۰۳
# 13              ۱۴۰۰
# 14               NaN
# 15              ۱۳۹۰
# 16               NaN
# 17              ۱۳۹۸
# 18              ۱۳۹۰
# 19               NaN

# %%
df['construction_year'].isna().sum()
# Out:
# 184172

# %%
df2 = df.copy()

# %%
persian_to_english = str.maketrans("۰۱۲۳۴۵۶۷۸۹", "0123456789")
def convert(x):
    if 'قبل' in str(x):
        return 1369
    elif not pd.notna(x) : return x
    return int(str(x).translate(persian_to_english))

df2['construction_year'] = df2['construction_year'].apply(convert)

# %%
for cat3 in df2['cat3_slug'].unique() :
    x = df2[df2['cat3_slug'] == cat3]['construction_year']
    print(f'{cat3} : ' , x.isnull().sum(), len(df))
# Out:
# villa :  12899 1000000
# apartment-sell :  5 1000000
# apartment-rent :  13 1000000
# office-rent :  70 1000000
# shop-sell :  11 1000000
# plot-old :  133569 1000000
# house-villa-sell :  15 1000000
# house-villa-rent :  11 1000000
# shop-rent :  30 1000000
# industry-agriculture-business-rent :  478 1000000
# office-sell :  0 1000000
# industry-agriculture-business-sell :  663 1000000
# presell :  15781 1000000
# suite-apartment :  16465 1000000
# partnership :  3622 1000000
# workspace :  539 1000000
# nan :  0 1000000

# %%
df2['cat2_slug'].unique()
# Out:
# array(['temporary-rent', 'residential-sell', 'residential-rent',
#        'commercial-rent', 'commercial-sell', 'real-estate-services'],
#       dtype=object)

# %%
df2.loc[df2['cat3_slug'] == 'plot-old', 'construction_year'] = 1370

# %%
df2['construction_year'].value_counts()
# Out:
# construction_year
# 1370.0    133570
# 1403.0    116259
# 1390.0     59139
# 1402.0     58424
# 1400.0     53674
# 1395.0     53029
# 1398.0     38207
# 1397.0     36326
# 1396.0     35487
# 1401.0     35328
# 1385.0     34065
# 1399.0     29594
# 1393.0     29094
# 1392.0     26130
# 1394.0     26110
# 1388.0     24268
# 1380.0     23480
# 1369.0     20637
# 1389.0     16755
# 1391.0     16316
# 1387.0     14136
# 1386.0     13468
# 1383.0      9894
# 1384.0      8494
# 1375.0      7247
# 1382.0      6965
# 1371.0      5531
# 1381.0      3590
# 1378.0      3025
# 1379.0      2415
# 1377.0      2117
# 1372.0      1914
# 1373.0      1827
# 1376.0      1593
# 1374.0      1289
# Name: count, dtype: int64

# %%
df2['construction_year'].dtype
# Out:
# dtype('float64')

# %%
df2['year_group'].hist(bins=8, figsize=(8,6))
plt.show()

# %%
df2["construction_year"].plot(kind="hist", bins=8, figsize=(8,6))
plt.show()
